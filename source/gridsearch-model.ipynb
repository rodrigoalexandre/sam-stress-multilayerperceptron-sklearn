# %% [markdown]
# #### Load the dataset.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors  import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble  import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

df = pd.read_csv('../dataset/preprocessed-sam-dataset.csv', sep='|',
                 dtype = {'CZ': 'float32', 'FZ': 'float32', 'Fp1': 'float32', 'F3': 'float32',
                          'FC1': 'float32', 'FC5': 'float32', 'FT9': 'float32', 'T7': 'float32',
                          'CP5': 'float32', 'P3': 'float32', 'P7': 'float32', 'PO9': 'float32',
                          'PZ': 'float32', 'O2': 'float32', 'P4': 'float32', 'CP6': 'float32',
                          'FT10': 'float32', 'FC6': 'float32', 'F8': 'float32', 'Fp2': 'float32',
                          'Scale': 'int8'})

# %% [markdown]
# #### Display the dataset size.

# %%
df.shape
# Out:
# (140800, 21)

# %% [markdown]
# #### GridSearch to evaluate KNN hyperparameters.

# %%
X = df.drop('Scale', axis = 1)
y = df['Scale']

model = KNeighborsClassifier(n_jobs = 4)

params = {
    'n_neighbors': [3, 7, 11, 21],
    'p': [1, 2],
    'leaf_size' : [1, 5]
}
strat_k_fold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
grid_search_cv = GridSearchCV(model, cv = strat_k_fold, param_grid = params, n_jobs = 4, verbose = 5)

grid_search_cv.fit(X, y)
print(grid_search_cv.best_params_)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# {'leaf_size': 1, 'n_neighbors': 21, 'p': 2}

# %% [markdown]
# #### GridSearch to evaluate Decision Tree hyperparameters.

# %%
X = df.drop('Scale', axis = 1)
y = df['Scale']

model = DecisionTreeClassifier(random_state = 42)

params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 7, 21, 51, 71]
}
strat_k_fold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
grid_search_cv = GridSearchCV(model, cv = strat_k_fold, param_grid = params, n_jobs = 4, verbose = 5)

grid_search_cv.fit(X, y)
print(grid_search_cv.best_params_)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'criterion': 'entropy', 'max_depth': 7}

# %% [markdown]
# #### GridSearch to evaluate Logistic Regression hyperparameters.

# %%
X = df.drop('Scale', axis = 1)
y = df['Scale']

model = LogisticRegression(random_state = 42, n_jobs = 4)

params = {
    'solver' : ['newton-cg', 'lbfgs', 'saga'],
    'multi_class' : ['ovr', 'multinomial']
}
strat_k_fold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
grid_search_cv = GridSearchCV(model, cv = strat_k_fold, param_grid = params, n_jobs = 4, verbose = 5)

grid_search_cv.fit(X, y)
print(grid_search_cv.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# {'multi_class': 'ovr', 'solver': 'newton-cg'}

# %% [markdown]
# #### GridSearch to evaluate Random Forest hyperparameters.

# %%
X = df.drop('Scale', axis = 1)
y = df['Scale']

model = RandomForestClassifier(random_state = 42, n_jobs = 4)

params = {
    'n_estimators': [100, 300],
    'max_depth': [7, 21, 41, 71],
    'criterion': ['gini', 'entropy']
}
strat_k_fold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
grid_search_cv = GridSearchCV(model, cv = strat_k_fold, param_grid = params, n_jobs = 4, verbose = 5)

grid_search_cv.fit(X, y)
print(grid_search_cv.best_params_)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# {'criterion': 'gini', 'max_depth': 21, 'n_estimators': 300}

# %% [markdown]
# #### GridSearch to evaluate Gradient Boosting hyperparameters.

# %%
X = df.drop('Scale', axis = 1)
y = df['Scale']

model = GradientBoostingClassifier(random_state = 42)

params = {
    'n_estimators': [100, 300],
    'max_depth': [3, 7, 21],
    'learning_rate': [0.01, 0.1, 0.2, 0.3, 1]
}
strat_k_fold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
grid_search_cv = GridSearchCV(model, cv = strat_k_fold, param_grid = params, n_jobs = 2, verbose = 5)

grid_search_cv.fit(X, y)
print(grid_search_cv.best_params_)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits

# %% [markdown]
# #### GridSearch to evaluate XGBoost hyperparameters.

# %%
X = df.drop('Scale', axis = 1)
y = df['Scale']

model = XGBClassifier(tree_method = 'gpu_hist')

params = {
    'max_depth': [3, 7, 21, 51]
}
strat_k_fold = StratifiedKFold(n_splits = 10, shuffle = True, random_state = 42)
grid_search_cv = GridSearchCV(model, cv = strat_k_fold, param_grid = params, n_jobs = 4, verbose = 5)

grid_search_cv.fit(X, y)
print(grid_search_cv.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 30 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:56:51] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:56:51] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:57:28] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:57:28] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:58:26] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:58:26] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:58:09] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:58:09] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:58:52] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:58:52] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 0
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:58:58] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:58:58] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:15] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:15] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:21] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:21] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:30] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:30] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:36] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:36] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:43] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:43] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:52] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:52] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [21:59:57] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [21:59:57] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:00:04] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:00:04] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:00:14] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:00:14] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:00:20] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:00:20] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:00:40] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:00:40] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:13] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:13] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:01] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:01] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:23] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:23] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:38] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:38] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:53] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:53] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:56] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:56] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 156738764
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:01:59] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:01:59] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:02:22] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:02:22] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 175613132
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:02:24] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:02:24] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 175613132
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:02:26] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:02:26] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 175613132
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:02:41] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:02:41] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:02:45] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:02:45] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:02:48] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/tree/updater_gpu_hist.cu:784: Exception in gpu_hist: [22:02:48] c:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1\xgboost\xgboost-ci-windows\src\data\../common/device_helpers.cuh:431: Memory allocation error on worker 0: bad allocation: cudaErrorMemoryAllocation: out of memory
# - Free memory: 433127220
# - Requested memory: 1073741824
#
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\DeveloperTools\anaconda3\envs\opencv\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.14502533 0.16033925 0.18483168        nan        nan        nan]
#   warnings.warn(
# {'max_depth': 7}
